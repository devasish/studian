# %% [markdown]
# <a href="https://colab.research.google.com/github/devasish/studian/blob/master/AIML/ml_data_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## wave data plot

# %%
# !pip install mglearn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import mglearn

X, y = mglearn.datasets.make_wave()
plt.figure() # Creates a new figure

plt.plot(X[:,0],y, 'o')
plt.xlabel('Feature')
plt.ylabel('Target')

plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.4/581.4 kB 7.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Discrete scatter of forge data

# %%
X, y = mglearn.datasets.make_forge()
print(X.shape, X.ndim, y.shape, y.ndim)
plt.figure()
mglearn.discrete_scatter(X[:,0], X[:,1], y)
plt.legend(['Class 0', 'Class 1'], loc=4)
plt.xlabel('Feature 1')
plt.ylabel('Featire 2')

plt.show()
# Out:
# (26, 2) 2 (26,) 1

# %% [markdown]
# # New section

# %%
mydata = [
    [2,3],
    [3,4]
]

X = np.array(mydata)

y = np.array([0,1])
print(y)

mglearn.discrete_scatter(X[:,0], X[:,1], y)
plt.legend(['Class 0', 'Class 1', 'class 2'], loc=4)
plt.xlabel('Feature')
plt.ylabel('Target')

plt.show()
# Out:
# [0 1]

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors as knearestneighbors
from matplotlib import pyplot as plt

cancer = load_breast_cancer()
print(cancer.data.shape, cancer.target.shape)
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=1)
num_neighbors = list(range(1, 10))
scores = []
for n in num_neighbors:
  model = knearestneighbors.KNeighborsClassifier(n_neighbors=n)
  model.fit(X_train, y_train)
  scores.append(model.score(X_test, y_test))
print(scores)
plt.figure()
plt.plot(num_neighbors, scores)
plt.xlabel('Number of neighbors')
plt.ylabel('Test accuracy')
plt.show()

# model = knearestneighbors.KNeighborsClassifier(n_neighbors=3)
# model.fit(X_train, y_train)
# print(model.score(X_test, y_test))
# Out:
# (569, 30) (569,)
# [0.9230769230769231, 0.9090909090909091, 0.9230769230769231, 0.9020979020979021, 0.9370629370629371, 0.9370629370629371, 0.9300699300699301, 0.9370629370629371, 0.9230769230769231]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
import json

cancer = load_breast_cancer()
print(cancer.data.shape, cancer.target.shape)
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=1)

print(f"cancder keys: {cancer.keys()}")
print(f"cancer features: {cancer.feature_names}")
print(f"cancer data shape: {cancer.data.shape}")
print(f"cancer target shape: {cancer.target.shape}")

# how does a data look
print("cancer data looks like this: ")
print(json.dumps(dict(zip(cancer.feature_names,cancer.data[0])), indent=4))

# count of differnt target names
print("count of differnt target names: ")
print({n: v for n,v in zip(cancer.target_names, np.bincount(cancer.target))})
# Out:
# (569, 30) (569,)
# cancder keys: dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# cancer features: ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']
# cancer data shape: (569, 30)
# cancer target shape: (569,)
# cancer data looks like this:
# {
#     "mean radius": 17.99,
#     "mean texture": 10.38,
#     "mean perimeter": 122.8,
#     "mean area": 1001.0,
#     "mean smoothness": 0.1184,
# ...
